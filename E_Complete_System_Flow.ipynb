# %% [markdown]
# # E. Complete System Flow

# %%
def full_system(cgpa, internship, aptitude, skills):
    internship_val = 1 if internship == "Yes" else 0

    # Dummy outputs (connect with real functions if needed)
    result = "Placed"
    prob = 85.0
    career = "Software Developer"

    return {
        "Prediction": result,
        "Probability": prob,
        "Career": career
    }

# %%
output = full_system(8.5, "Yes", 78, 85)
print(output)
